# %% [markdown]
# # Install dependencies

# %%
# !pip install -r requirements.txt #Please unlock torch installation if you are working in local in requirements file
# Out:
# ...
#   Cloning https://github.com/jorgemasgomez/sahi.git (to revision 8edc121a6744b70ab8fcc7fbf1aca58d18aa5eef) to c:\users\pheno\appdata\local\temp\pip-install-ilugts77\sahi_97449903523c4e4b8622afdccda3d9be
#   Resolved https://github.com/jorgemasgomez/sahi.git to commit 8edc121a6744b70ab8fcc7fbf1aca58d18aa5eef
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# ...
#   Created wheel for sahi: filename=sahi-0.11.18-py3-none-any.whl size=114671 sha256=3607835e34ed1d6df484410e7a9e4aa8be09572230952a8f2629d038dcca9034
# ...

# %%
# !pip freeze
# Out:
# absl-py==2.1.0
# adjustText==1.1.1
# altair==5.4.1
# anyio==4.2.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# astor==0.8.1
# asttokens==2.4.1
# astunparse==1.6.3
# async-lru==2.0.4
# attrs==24.2.0
# babel==2.16.0
# beautifulsoup4==4.12.3
# bleach==6.2.0
# certifi==2024.2.2
# cffi==1.16.0
# chardet==5.2.0
# charset-normalizer==3.3.2
# click==8.1.7
# cloudpickle==3.1.0
# clr-loader==0.2.6
# colorama==0.4.6
# comm==0.2.1
# comtypes==1.1.9
# contourpy==1.3.0
# cuda-python==11.8.3
# cupy==13.2.0
# cv2_enumerate_cameras==1.1.7
# cycler==0.12.1
# dask==2024.10.0
# dask-jobqueue==0.9.0
# debugpy==1.8.0
# decorator==5.1.1
# defusedxml==0.7.1
# distributed==2024.10.0
# distro==1.9.0
# easyocr==1.7.2
# et-xmlfile==1.1.0
# executing==2.0.1
# fastjsonschema==2.20.0
# fastrlock==0.8.2
# filelock==3.16.1
# fire==0.6.0
# flatbuffers==24.3.7
# fonttools==4.54.1
# fpdf==1.7.2
# fqdn==1.5.1
# fsspec==2024.10.0
# gast==0.5.4
# git-filter-repo==2.38.0
# google-pasta==0.2.0
# ...
